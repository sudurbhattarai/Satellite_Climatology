# %% [markdown]
# # Satellite Climatology: Remote Sensing of a Changing Climate: Exercises - 2
# ## Climatological analysis of clouds
#
# Hendrik Andersen, contact: hendrik.andersen@kit.edu

# %%
# import relevant modules first
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# define the path to the data
dataDir = "../data/"

# open the data
ds = xr.open_dataset(dataDir+"2001_2020_modis_monthly_l3_teaching.nc", engine="netcdf4")
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 228, latitude: 180, longitude: 360)
# Coordinates:
#   * time       (time) datetime64[ns] 2001-01-15 2001-02-15 ... 2020-12-15
#   * latitude   (latitude) float32 89.5 88.5 87.5 86.5 ... -87.5 -88.5 -89.5
#   * longitude  (longitude) float32 -179.5 -178.5 -177.5 ... 177.5 178.5 179.5
# Data variables:
#     CLF        (time, latitude, longitude) float64 ...
#     DER        (time, latitude, longitude) float64 ...
#     LWP        (time, latitude, longitude) float64 ...
#     IWP        (time, latitude, longitude) float64 ...
#     CTT        (time, latitude, longitude) float64 ...
#     CTH        (time, latitude, longitude) float64 ...
#     AOD        (time, latitude, longitude) float64 ...

# %% [markdown]
# The dataset "2001_2020_modis_monthly_l3_teaching.nc" contains monthly data on clouds and aerosols, and contains the following variables that point to the following variables in the original MOD08_M3 files:
# - CLF: Cloud_Fraction_Mean_Mean
# - DER: Cloud_Effective_Radius_Liquid_Mean_Mean
# - LWP: Cloud_Water_Path_Liquid_Mean_Mean
# - IWP: Cloud_Water_Path_Ice_Mean_Mean
# - CTT: Cloud_Top_Temperature_Mean_Mean
# - CTH: Cloud_Top_Height_Mean_Mean
# - AOD: Aerosol_Optical_Depth_Land_Ocean_Mean_Mean

# %% [markdown]
# Tasks:
# 1. Use the script from last week to create climatological maps of the mean state and variability of cloud occurrence and properties.
# 2. Analyse the climatological seasonal cycle by plotting seasonal average maps for cloud parameters.
# 3. Calculate the seasonal differences (JJA-DJF or vice versa) and plot these on a map.
# 4. Use the file trend_calculation.py to calculate the linear temporal trend of cloud properties as unit/decade and test for significance (you can import the file as a module like this: from trend_calculation import xr_trend as trend). Plot a map of the trend of cloud properties where they are significant (pval < 0.05).
# 5. Describe your findings: Have there been spatially coherent and significant trends in clouds that could be observed over the last 2 decades? Can you make some general statements if and to what degree clouds have been changing over the last two decades?

# %%
# Example map showing the climatological average cloud fraction

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111, projection=ccrs.Robinson())
ax.coastlines()
im = ax.pcolormesh(ds.longitude, ds.latitude, ds.CLF.mean('time'), transform=ccrs.PlateCarree())
plt.colorbar(im)
plt.show()
